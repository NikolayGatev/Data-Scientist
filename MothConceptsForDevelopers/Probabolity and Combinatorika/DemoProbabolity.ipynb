# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

from collections import Counter

# %% [markdown]
# # Probability and Combinatorics
# # Demo

# %%
results = np.random.randint(1, 7, size = 10000000)

# %%
plt.plot(results) # визуализация графиката показва всяка стойност - не се използва за дискретни променливи
plt.xlabel('# trial')
plt.ylabel('Result')
plt.show()

# %%
count = Counter(results) # създава речник с ключ всеки различен елемент и стойност броя срещания

# %%
count
# Out:
# Counter({5: 1668154,
#          2: 1667432,
#          3: 1667043,
#          4: 1666063,
#          6: 1665693,
#          1: 1665615})

# %%
plt.hist(results, bins = range(1, 8))
# Out:
# (array([1665615., 1667432., 1667043., 1666063., 1668154., 1665693.]),
#  array([1., 2., 3., 4., 5., 6., 7.]),
#  <BarContainer object of 6 artists>)

# %%
plt.bar(count.keys(), count.values())
# Out:
# <BarContainer object of 6 artists>
